# %%
output_path = "/opt/consumer-output-delta-lake/delta-trades-stream-5s-table"
checkpoint_path = "/opt/consumer-output-delta-lake/checkpoints/delta-trades-stream-5s-table"
ram_limit = 4

from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import (
    StructType, StructField,
    StringType, LongType, DoubleType
)

# %% [markdown]
# ## 1. Create spark app and read from kafka stream

# %%
# --------------------------------------------------
# 1. Create Spark session WITH DELTA LAKE SUPPORT
# --------------------------------------------------
spark = (
    SparkSession.builder
    .appName("KafkaStreamingToConsole")
    .config("spark.ui.port", "4042")
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension")
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog")
    .config("spark.driver.memory", f"{ram_limit}g")  # or 6g if you have RAM
    .config("spark.driver.extraJavaOptions", "-XX:+UseG1GC")
    .getOrCreate()
)

spark.sparkContext.setLogLevel("WARN")

# --------------------------------------------------
# 2. Read from Kafka (STREAMING)
# --------------------------------------------------
df = (
    spark.readStream
    .format("kafka")
    .option("kafka.bootstrap.servers", "kafka:9092")
    .option("subscribe", "trades.raw")
    .option("startingOffsets", "latest")
    .load()
)
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/12/29 17:55:09 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %% [markdown]
# ## 2. Data transformation

# %%
# --------------------------------------------------
# 3-7. Transformations (unchanged)
# --------------------------------------------------
df2 = df.select(
    col("key").cast("string").alias("key"),
    col("value").cast("string").alias("value"),
    col("topic"),
    col("partition"),
    col("offset"),
    col("timestamp")
)

value_schema = StructType([
    StructField("exchange", StringType(), True),
    StructField("symbol", StringType(), True),
    StructField("trade_id", LongType(), True),
    StructField("side", StringType(), True),
    StructField("price", DoubleType(), True),
    StructField("size", DoubleType(), True),
    StructField("exchange_time", StringType(), True),
    StructField("ingest_time", StringType(), True),
])

df_parsed = df2.withColumn("value_json", from_json(col("value"), value_schema))

df_flat = df_parsed.select(
    col("offset"),
    col("key"),
    col("value_json.symbol").alias("symbol"),
    col("value_json.trade_id").alias("trade_id"),
    col("value_json.side").alias("side"),
    col("value_json.price").alias("price"),
    col("value_json.size").alias("size"),
    col("value_json.exchange_time").alias("exchange_time"),
    col("value_json.ingest_time").alias("ingest_time"),
)

df_final = (
    df_flat
    .withColumn("offset", col("offset").cast("long"))
    .withColumn("trade_id", col("trade_id").cast("long"))
    .withColumn("price", col("price").cast("double"))
    .withColumn("size", col("size").cast("double"))

    .withColumn("exchange_time_ts", from_utc_timestamp(to_timestamp("exchange_time"), "Asia/Bangkok").cast("timestamp"))
    .withColumn("ingest_time_ts", from_utc_timestamp(to_timestamp("ingest_time"), "Asia/Bangkok").cast("timestamp"))
    .withColumn("ingest_time_minute", date_trunc("minute", col("ingest_time_ts")).cast("timestamp"))

    .withColumn("exchange_second", second("exchange_time_ts").cast("int"))
    .withColumn("exchange_minute", minute("exchange_time_ts").cast("int"))
    .withColumn("exchange_hour", hour("exchange_time_ts").cast("int"))
    .withColumn("exchange_day", dayofmonth("exchange_time_ts").cast("int"))
    .withColumn("exchange_month", month("exchange_time_ts").cast("int"))

    .withColumn("hour_id", date_format("ingest_time_ts", "yyyyMMddHH").cast("string"))
)

# --------------------------------------------------
# 8. DISPLAY STREAMING RESULTS TO CONSOLE ✅
# --------------------------------------------------
# query = (
#     df_final.writeStream
#     .outputMode("append")
#     .format("console")          # ← Prints to stdout
#     .option("truncate", False)  # ← Show full column content
#     .option("numRows", 20)      # ← Show up to 20 rows per batch
#     .start()
# )

# print("Streaming started. Watching Kafka topic 'trades.raw'...")
# query.awaitTermination()  # Keeps the stream alive

# %% [markdown]
# ## 3. Write to delta stream table with checkpoint

# %%
# --------------------------------------------------
# 4. Write stream to Delta (CHECKPOINT IS CRITICAL)
# --------------------------------------------------
query = (
    df_final.writeStream
    .format("delta")
    .outputMode("append")
    .trigger(processingTime='5 seconds')  # ← ADD THIS LINE
    .option("checkpointLocation", checkpoint_path)
    .partitionBy("hour_id")          # ✅ PARTITION HERE
    .start(output_path)
)

print("Streaming started → writing to Delta")
query.awaitTermination()
# Out:
# 25/12/29 09:24:46 WARN ResolveWriteToStream: spark.sql.adaptive.enabled is not supported in streaming DataFrames/Datasets and will be disabled.
# Streaming started → writing to Delta
# 25/12/29 09:24:54 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 7721 milliseconds
# 25/12/29 09:24:55 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# 25/12/29 09:24:59 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5677 milliseconds
# 25/12/29 09:25:05 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5122 milliseconds
# 25/12/29 09:25:11 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5913 milliseconds
# 25/12/29 09:33:15 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5335 milliseconds
# 25/12/29 09:34:05 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5468 milliseconds
# 25/12/29 09:34:55 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5705 milliseconds
# 25/12/29 09:35:45 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5753 milliseconds
# 25/12/29 09:36:36 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6410 milliseconds
# 25/12/29 09:38:15 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5950 milliseconds
# 25/12/29 09:39:11 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 11100 milliseconds
# 25/12/29 09:40:02 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 7213 milliseconds
# 25/12/29 09:40:52 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 7616 milliseconds
# 25/12/29 09:41:36 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6880 milliseconds
# 25/12/29 09:41:44 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 7782 milliseconds
# 25/12/29 09:42:30 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5701 milliseconds
# 25/12/29 09:43:23 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 8699 milliseconds
# 25/12/29 09:44:13 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 8365 milliseconds
# 25/12/29 09:45:03 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 8495 milliseconds
# 25/12/29 09:45:30 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5019 milliseconds
# 25/12/29 09:45:35 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5037 milliseconds
# 25/12/29 09:45:57 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 12451 milliseconds
# 25/12/29 09:46:46 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6900 milliseconds
# 25/12/29 09:47:41 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 11911 milliseconds
# 25/12/29 09:47:47 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5157 milliseconds
# 25/12/29 09:48:06 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 9485 milliseconds
# 25/12/29 09:48:15 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5112 milliseconds
# 25/12/29 09:48:20 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5128 milliseconds
# 25/12/29 09:48:25 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5179 milliseconds
# 25/12/29 09:48:30 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5171 milliseconds
# 25/12/29 09:48:38 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 7747 milliseconds
# 25/12/29 09:48:43 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5132 milliseconds
# 25/12/29 09:48:48 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5132 milliseconds
# 25/12/29 09:48:53 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5084 milliseconds
# 25/12/29 09:48:58 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5061 milliseconds
# 25/12/29 09:49:06 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5053 milliseconds
# 25/12/29 09:49:11 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5354 milliseconds
# 25/12/29 09:49:16 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5153 milliseconds
# 25/12/29 09:49:22 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5132 milliseconds
# 25/12/29 09:49:29 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 7343 milliseconds
# 25/12/29 09:49:34 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5390 milliseconds
# 25/12/29 09:49:39 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5145 milliseconds
# 25/12/29 09:49:45 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5303 milliseconds
# 25/12/29 09:49:50 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5209 milliseconds
# 25/12/29 09:49:55 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5294 milliseconds
# 25/12/29 09:50:05 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5343 milliseconds
# 25/12/29 09:50:10 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5389 milliseconds
# 25/12/29 09:50:25 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 10032 milliseconds
# 25/12/29 09:50:35 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5446 milliseconds
# 25/12/29 09:50:40 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5372 milliseconds
# 25/12/29 09:50:46 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5353 milliseconds
# 25/12/29 09:50:51 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5434 milliseconds
# 25/12/29 09:51:00 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5587 milliseconds
# 25/12/29 09:51:06 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5564 milliseconds
# 25/12/29 09:51:11 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5554 milliseconds
# 25/12/29 09:51:22 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 10508 milliseconds
# 25/12/29 09:51:31 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5568 milliseconds
# 25/12/29 09:51:37 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5697 milliseconds
# 25/12/29 09:51:42 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5716 milliseconds
# 25/12/29 09:51:48 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5803 milliseconds
# 25/12/29 09:51:58 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5880 milliseconds
# 25/12/29 09:52:04 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5725 milliseconds
# 25/12/29 09:52:10 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6005 milliseconds
# 25/12/29 09:52:18 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 8464 milliseconds
# 25/12/29 09:52:24 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5623 milliseconds
# 25/12/29 09:52:29 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5478 milliseconds
# 25/12/29 09:52:35 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5553 milliseconds
# 25/12/29 09:52:40 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5713 milliseconds
# 25/12/29 09:52:50 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5834 milliseconds
# 25/12/29 09:52:56 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5851 milliseconds
# 25/12/29 09:53:02 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5748 milliseconds
# 25/12/29 09:53:08 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6007 milliseconds
# 25/12/29 09:53:17 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 8839 milliseconds
# 25/12/29 09:53:23 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5751 milliseconds
# 25/12/29 09:53:28 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5722 milliseconds
# 25/12/29 09:53:34 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5694 milliseconds
# 25/12/29 09:53:40 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5799 milliseconds
# 25/12/29 09:53:50 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5761 milliseconds
# 25/12/29 09:53:56 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5828 milliseconds
# 25/12/29 09:54:02 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5799 milliseconds
# 25/12/29 09:54:08 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5823 milliseconds
# 25/12/29 09:54:17 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 8985 milliseconds
# 25/12/29 09:54:23 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5898 milliseconds
# 25/12/29 09:54:28 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5641 milliseconds
# 25/12/29 09:54:34 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5889 milliseconds
# 25/12/29 09:54:44 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5895 milliseconds
# 25/12/29 09:54:50 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5801 milliseconds
# 25/12/29 09:54:56 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5917 milliseconds
# 25/12/29 09:55:01 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5902 milliseconds
# 25/12/29 09:55:17 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 11055 milliseconds
# 25/12/29 09:55:23 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5994 milliseconds
# 25/12/29 09:55:28 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5491 milliseconds
# 25/12/29 09:55:34 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5948 milliseconds
# 25/12/29 09:55:44 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5974 milliseconds
# 25/12/29 09:55:50 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5958 milliseconds
# 25/12/29 09:55:56 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6039 milliseconds
# 25/12/29 09:56:01 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5193 milliseconds
# 25/12/29 09:56:18 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 11467 milliseconds
# 25/12/29 09:56:24 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6062 milliseconds
# 25/12/29 09:56:30 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6027 milliseconds
# 25/12/29 09:56:41 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6038 milliseconds
# 25/12/29 09:56:47 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6205 milliseconds
# 25/12/29 09:56:53 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6105 milliseconds
# 25/12/29 09:57:03 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6137 milliseconds
# 25/12/29 09:57:09 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6184 milliseconds
# 25/12/29 09:57:21 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 11247 milliseconds
# 25/12/29 09:57:31 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5843 milliseconds
# 25/12/29 09:57:37 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6232 milliseconds
# 25/12/29 09:57:43 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6202 milliseconds
# 25/12/29 09:57:49 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5882 milliseconds
# 25/12/29 09:58:00 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6280 milliseconds
# 25/12/29 09:58:06 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6226 milliseconds
# 25/12/29 09:58:12 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6166 milliseconds
# 25/12/29 09:58:22 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 9874 milliseconds
# 25/12/29 09:58:28 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6367 milliseconds
# 25/12/29 09:58:35 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6480 milliseconds
# 25/12/29 09:58:41 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6290 milliseconds
# 25/12/29 09:58:47 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6295 milliseconds
# 25/12/29 09:58:58 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6376 milliseconds
# 25/12/29 09:59:04 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6249 milliseconds
# 25/12/29 09:59:10 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6310 milliseconds
# 25/12/29 09:59:17 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6303 milliseconds
# 25/12/29 09:59:27 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 10134 milliseconds
# 25/12/29 09:59:33 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6491 milliseconds
# 25/12/29 09:59:40 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6364 milliseconds
# 25/12/29 09:59:45 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5584 milliseconds
# 25/12/29 09:59:51 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5401 milliseconds
# 25/12/29 09:59:57 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6428 milliseconds
# 25/12/29 10:00:04 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6359 milliseconds
# 25/12/29 10:00:10 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6546 milliseconds
# 25/12/29 10:00:21 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6347 milliseconds
# 25/12/29 10:00:33 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 12264 milliseconds
# 25/12/29 10:00:40 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6589 milliseconds
# 25/12/29 10:00:51 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6690 milliseconds
# 25/12/29 10:00:58 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6705 milliseconds
# 25/12/29 10:01:04 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6516 milliseconds
# 25/12/29 10:01:16 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6555 milliseconds
# 25/12/29 10:01:22 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6509 milliseconds
# 25/12/29 10:01:29 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6887 milliseconds
# 25/12/29 10:01:40 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 10971 milliseconds
# 25/12/29 10:01:47 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 7092 milliseconds
# 25/12/29 10:01:54 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6976 milliseconds
# 25/12/29 10:02:01 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6803 milliseconds
# 25/12/29 10:02:06 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5027 milliseconds
# 25/12/29 10:02:13 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6705 milliseconds
# 25/12/29 10:02:19 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6751 milliseconds
# 25/12/29 10:02:26 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6683 milliseconds
# 25/12/29 10:02:33 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6835 milliseconds
# 25/12/29 10:02:50 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 12741 milliseconds
# 25/12/29 10:02:57 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 7031 milliseconds
# 25/12/29 10:03:02 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5040 milliseconds
# 25/12/29 10:03:10 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 7141 milliseconds
# 25/12/29 10:03:17 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 7286 milliseconds
# 25/12/29 10:03:24 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6781 milliseconds
# 25/12/29 10:03:30 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6391 milliseconds
# 25/12/29 10:03:42 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6762 milliseconds
# 25/12/29 10:03:48 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6867 milliseconds
# 25/12/29 10:04:00 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 11106 milliseconds
# 25/12/29 10:04:07 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6968 milliseconds
# 25/12/29 10:04:13 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6754 milliseconds
# 25/12/29 10:04:20 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6765 milliseconds
# 25/12/29 10:04:32 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6825 milliseconds
# 25/12/29 10:04:39 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6936 milliseconds
# 25/12/29 10:04:45 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6874 milliseconds
# 25/12/29 10:04:52 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6899 milliseconds
# 25/12/29 10:05:11 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 13220 milliseconds
# 25/12/29 10:05:18 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 7001 milliseconds
# 25/12/29 10:05:30 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6981 milliseconds
# 25/12/29 10:05:36 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6930 milliseconds
# 25/12/29 10:05:43 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6979 milliseconds
# 25/12/29 10:05:49 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5108 milliseconds
# 25/12/29 10:05:56 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 7082 milliseconds
# 25/12/29 10:06:03 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 7160 milliseconds
# 25/12/29 10:06:10 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 7245 milliseconds
# 25/12/29 10:06:22 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 11785 milliseconds
# 25/12/29 10:06:29 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 7459 milliseconds
# 25/12/29 10:06:36 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6979 milliseconds
# 25/12/29 10:06:43 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 7218 milliseconds
# 25/12/29 10:06:55 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 7158 milliseconds
# 25/12/29 10:07:02 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 7239 milliseconds
# 25/12/29 10:07:10 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 7373 milliseconds
# 25/12/29 10:07:15 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5101 milliseconds
# 25/12/29 10:07:22 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 7097 milliseconds
# 25/12/29 10:07:36 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 13662 milliseconds
# 25/12/29 10:07:41 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5247 milliseconds
# 25/12/29 10:07:48 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 7176 milliseconds
# 25/12/29 10:07:55 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 7139 milliseconds
# 25/12/29 10:08:03 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 7341 milliseconds
# 25/12/29 10:08:09 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6518 milliseconds
# 25/12/29 10:08:15 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6176 milliseconds
# 25/12/29 10:08:23 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 7287 milliseconds
# 25/12/29 10:08:30 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 7014 milliseconds
# 25/12/29 10:08:37 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 7180 milliseconds
# 25/12/29 10:08:48 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 11368 milliseconds
# 25/12/29 10:08:55 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 7302 milliseconds
# 25/12/29 10:09:03 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 7175 milliseconds
# 25/12/29 10:09:08 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5525 milliseconds
# 25/12/29 10:09:15 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6835 milliseconds
# 25/12/29 10:09:23 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 7700 milliseconds
# 25/12/29 10:09:30 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 7635 milliseconds
# 25/12/29 10:09:36 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5356 milliseconds
# 25/12/29 10:09:43 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 7302 milliseconds
# 25/12/29 10:09:50 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 7309 milliseconds
# 25/12/29 10:10:02 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 12173 milliseconds
# 25/12/29 10:10:10 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 7441 milliseconds
# 25/12/29 10:10:17 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 7437 milliseconds
# 25/12/29 10:10:25 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 7550 milliseconds
# 25/12/29 10:10:30 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5481 milliseconds
# 25/12/29 10:10:38 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 7604 milliseconds
# 25/12/29 10:10:46 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 7619 milliseconds
# 25/12/29 10:10:53 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 7030 milliseconds
# 25/12/29 10:10:58 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5827 milliseconds
# 25/12/29 10:11:06 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 7621 milliseconds
# 25/12/29 10:11:21 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 14885 milliseconds
# 25/12/29 10:11:26 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5501 milliseconds
# 25/12/29 10:11:34 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 7168 milliseconds
# 25/12/29 10:11:41 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 7780 milliseconds
# 25/12/29 10:11:49 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 7373 milliseconds
# 25/12/29 10:11:54 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5547 milliseconds
# 25/12/29 10:12:02 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 7354 milliseconds
# 25/12/29 10:12:10 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 7863 milliseconds
# 25/12/29 10:12:17 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 7810 milliseconds
# 25/12/29 10:12:23 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5848 milliseconds
# 25/12/29 10:12:38 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 14663 milliseconds
# 25/12/29 10:12:46 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 7671 milliseconds
# 25/12/29 10:12:51 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5693 milliseconds
# 25/12/29 10:12:59 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 7753 milliseconds
# 25/12/29 10:13:07 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 7849 milliseconds
# 25/12/29 10:13:14 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 7513 milliseconds
# 25/12/29 10:13:20 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5845 milliseconds
# 25/12/29 10:13:27 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 7278 milliseconds
# 25/12/29 10:13:35 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 7681 milliseconds
# 25/12/29 10:13:43 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 7861 milliseconds
# 25/12/29 10:13:56 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 12925 milliseconds
# 25/12/29 10:14:04 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 7905 milliseconds
# 25/12/29 10:14:12 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 8079 milliseconds
# 25/12/29 10:14:18 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5995 milliseconds
# 25/12/29 10:14:26 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 7864 milliseconds
# 25/12/29 10:14:34 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 7786 milliseconds
# 25/12/29 10:14:41 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 7936 milliseconds
# 25/12/29 10:14:48 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6392 milliseconds
# 25/12/29 10:14:56 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 7970 milliseconds
# 25/12/29 10:15:04 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 7920 milliseconds
# 25/12/29 10:15:17 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 13263 milliseconds
# 25/12/29 10:15:25 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 7993 milliseconds
# 25/12/29 10:15:33 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 7494 milliseconds
# 25/12/29 10:15:39 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 6338 milliseconds
# 25/12/29 10:15:47 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 8074 milliseconds
# 25/12/29 10:15:55 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 8147 milliseconds
# 25/12/29 10:16:03 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 8272 milliseconds
# 25/12/29 10:16:09 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 5926 milliseconds
# 25/12/29 10:16:17 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 7904 milliseconds
# 25/12/29 10:16:25 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 8299 milliseconds
# 25/12/29 10:16:39 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 13446 milliseconds
# 25/12/29 10:16:47 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 8074 milliseconds
