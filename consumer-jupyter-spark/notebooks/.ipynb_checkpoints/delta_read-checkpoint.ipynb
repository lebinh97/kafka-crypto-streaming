# %%
from pyspark.sql import SparkSession
from delta.tables import DeltaTable
# !pwd
# batch_table_path = "/opt/consumer-output-delta-lake/delta-trades-batch-table"
# stream_table_path = "/opt/consumer-output-delta-lake/delta-trades-stream-5s-table"

batch_table_path = "/opt/consumer-output-iceberg/delta-trades-batch-table"
stream_table_path = "/opt/consumer-output-iceberg/delta-trades-stream-5s-table"
# Out:
# /opt/workspace

# %% [markdown]
# ## 1. Table description

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("DeltaInspect") \
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") \
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog") \
    .getOrCreate()

# 1️⃣ ✅ SCHEMA + PARTITIONING + LOCATION + etc.
print("=== TABLE STRUCTURE (DESCRIBE DETAIL) ===")
spark.sql(f"DESCRIBE DETAIL delta.`{stream_table_path}`").show(truncate=True)

# 2️⃣ ✅ WRITE HISTORY (includes file count, row count, size)
print("\n=== LAST WRITE METRICS (DESCRIBE HISTORY) ===")
spark.sql(f"DESCRIBE HISTORY delta.`{stream_table_path}`").select(
    "version", "timestamp", "operation", "operationMetrics"
).show(truncate=False)

# 3️⃣ ✅ RAW SCHEMA (if you just want column names/types)
print("\n=== SCHEMA ONLY ===")
spark.sql(f"DESCRIBE delta.`{stream_table_path}`").show(30)
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/12/30 07:57:30 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# === TABLE STRUCTURE (DESCRIBE DETAIL) ===
# 25/12/30 07:57:44 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# +------+--------------------+----+-----------+--------------------+--------------------+--------------------+----------------+-----------------+--------+-----------+----------+----------------+----------------+--------------------+
# |format|                  id|name|description|            location|           createdAt|        lastModified|partitionColumns|clusteringColumns|numFiles|sizeInBytes|properties|minReaderVersion|minWriterVersion|       tableFeatures|
# +------+--------------------+----+-----------+--------------------+--------------------+--------------------+----------------+-----------------+--------+-----------+----------+----------------+----------------+--------------------+
# | delta|b27f96a9-c8aa-46b...|NULL|       NULL|file:/opt/consume...|2025-12-30 07:33:...|2025-12-30 07:57:...|              []|               []|    1083|    3869919|        {}|               1|               2|[appendOnly, inva...|
# +------+--------------------+----+-----------+--------------------+--------------------+--------------------+----------------+-----------------+--------+-----------+----------+----------------+----------------+--------------------+
#
#
# === LAST WRITE METRICS (DESCRIBE HISTORY) ===
# +-------+-----------------------+----------------+----------------------------------------------------------------------------------------+
# |version|timestamp              |operation       |operationMetrics                                                                        |
# +-------+-----------------------+----------------+----------------------------------------------------------------------------------------+
# |272    |2025-12-30 07:57:50.304|STREAMING UPDATE|{numRemovedFiles -> 0, numOutputRows -> 16, numOutputBytes -> 10337, numAddedFiles -> 3}|
# |271    |2025-12-30 07:57:43.899|STREAMING UPDATE|{numRemovedFiles -> 0, numOutputRows -> 31, numOutputBytes -> 14070, numAddedFiles -> 4}|
# |270    |2025-12-30 07:57:35.927|STREAMING UPDATE|{numRemovedFiles -> 0, numOutputRows -> 39, numOutputBytes -> 14411, numAddedFiles -> 4}|
# |269    |2025-12-30 07:57:30.137|STREAMING UPDATE|{numRemovedFiles -> 0, numOutputRows -> 47, numOutputBytes -> 14428, numAddedFiles -> 4}|
# |268    |2025-12-30 07:57:24.921|STREAMING UPDATE|{numRemovedFiles -> 0, numOutputRows -> 12, numOutputBytes -> 13217, numAddedFiles -> 4}|
# |267    |2025-12-30 07:57:19.988|STREAMING UPDATE|{numRemovedFiles -> 0, numOutputRows -> 49, numOutputBytes -> 17785, numAddedFiles -> 5}|
# |266    |2025-12-30 07:57:15.218|STREAMING UPDATE|{numRemovedFiles -> 0, numOutputRows -> 16, numOutputBytes -> 16648, numAddedFiles -> 5}|
# |265    |2025-12-30 07:57:10.221|STREAMING UPDATE|{numRemovedFiles -> 0, numOutputRows -> 11, numOutputBytes -> 16465, numAddedFiles -> 5}|
# |264    |2025-12-30 07:57:05.345|STREAMING UPDATE|{numRemovedFiles -> 0, numOutputRows -> 25, numOutputBytes -> 13798, numAddedFiles -> 4}|
# |263    |2025-12-30 07:57:00.523|STREAMING UPDATE|{numRemovedFiles -> 0, numOutputRows -> 19, numOutputBytes -> 13560, numAddedFiles -> 4}|
# |262    |2025-12-30 07:56:55.459|STREAMING UPDATE|{numRemovedFiles -> 0, numOutputRows -> 27, numOutputBytes -> 10785, numAddedFiles -> 3}|
# |261    |2025-12-30 07:56:50.509|STREAMING UPDATE|{numRemovedFiles -> 0, numOutputRows -> 46, numOutputBytes -> 17945, numAddedFiles -> 5}|
# |260    |2025-12-30 07:56:41.23 |STREAMING UPDATE|{numRemovedFiles -> 0, numOutputRows -> 43, numOutputBytes -> 14219, numAddedFiles -> 4}|
# |259    |2025-12-30 07:56:36.385|STREAMING UPDATE|{numRemovedFiles -> 0, numOutputRows -> 24, numOutputBytes -> 16943, numAddedFiles -> 5}|
# |258    |2025-12-30 07:56:31.499|STREAMING UPDATE|{numRemovedFiles -> 0, numOutputRows -> 19, numOutputBytes -> 13502, numAddedFiles -> 4}|
# |257    |2025-12-30 07:56:26.528|STREAMING UPDATE|{numRemovedFiles -> 0, numOutputRows -> 39, numOutputBytes -> 14216, numAddedFiles -> 4}|
# |256    |2025-12-30 07:56:21.762|STREAMING UPDATE|{numRemovedFiles -> 0, numOutputRows -> 29, numOutputBytes -> 13986, numAddedFiles -> 4}|
# |255    |2025-12-30 07:56:16.966|STREAMING UPDATE|{numRemovedFiles -> 0, numOutputRows -> 29, numOutputBytes -> 13961, numAddedFiles -> 4}|
# |254    |2025-12-30 07:56:11.862|STREAMING UPDATE|{numRemovedFiles -> 0, numOutputRows -> 13, numOutputBytes -> 13238, numAddedFiles -> 4}|
# |253    |2025-12-30 07:56:07.579|STREAMING UPDATE|{numRemovedFiles -> 0, numOutputRows -> 50, numOutputBytes -> 18042, numAddedFiles -> 5}|
# +-------+-----------------------+----------------+----------------------------------------------------------------------------------------+
# only showing top 20 rows
#
#
# === SCHEMA ONLY ===
# +----------------+---------+-------+
# |        col_name|data_type|comment|
# +----------------+---------+-------+
# |          offset|   bigint|   NULL|
# |          symbol|   string|   NULL|
# |        trade_id|   bigint|   NULL|
# |            side|   string|   NULL|
# |           price|   double|   NULL|
# |            size|   double|   NULL|
# |   exchange_time|   string|   NULL|
# |     ingest_time|   string|   NULL|
# |exchange_time_ts|timestamp|   NULL|
# |         hour_id|   string|   NULL|
# +----------------+---------+-------+

# %% [markdown]
# ## 2. Table query

# %% [markdown]
# ### 2.1. Batch table query

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("DeltaRead") \
    .config("spark.ui.port", "4041") \
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") \
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog") \
    .config("spark.sql.catalogImplementation", "in-memory") \
    .getOrCreate()

# Now this should work in OSS Delta Lake 3.2.0 + Spark 3.5.1
files_df = spark.sql(f"SELECT * FROM delta.`{batch_table_path}`")
print('Partitions from reading delta lake: ', files_df.rdd.getNumPartitions())
files_df.createOrReplaceTempView("batch_trades")
# files_df.show(5, truncate=True)
# Out:
# 25/12/29 08:47:08 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.
# Partitions from reading delta lake:  12

# %%
df_batch_check = spark.sql(f"""
    SELECT
    exchange_minute, exchange_hour, count(distinct trade_id) as trade_cnt
    FROM batch_trades
    where exchange_day = 29
    group by 1, 2
    order by 2 desc, 1 desc
""").show(20)

# %% [markdown]
# ### 2.2. Stream table query

# %% [markdown]
# #### 2.2.1. Read stream table

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("DeltaRead") \
    .config("spark.ui.port", "4043") \
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") \
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog") \
    .config("spark.sql.catalogImplementation", "in-memory") \
    .getOrCreate()

df_stream = spark.sql(f"SELECT * FROM delta.`{stream_table_path}`")
print('Partitions from reading df_stream: ', df_stream.rdd.getNumPartitions())
df_stream.createOrReplaceTempView("stream_trades")
df_stream.show(5, truncate=True)
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/01/01 06:12:58 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 26/01/01 06:13:56 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# Partitions from reading df_stream:  11
# +------+-------+---------+----+-------+-------+--------------------+--------------------+--------------------+----------+
# |offset| symbol| trade_id|side|  price|   size|       exchange_time|         ingest_time|    exchange_time_ts|   hour_id|
# +------+-------+---------+----+-------+-------+--------------------+--------------------+--------------------+----------+
# |684175|ETH-USD|751204804|sell|2971.14| 3.5E-7|2026-01-01T05:01:...|2026-01-01T05:01:...|2026-01-01 12:01:...|2026010112|
# |684176|ETH-USD|751204805|sell|2971.14| 7.8E-7|2026-01-01T05:01:...|2026-01-01T05:01:...|2026-01-01 12:01:...|2026010112|
# |684177|ETH-USD|751204806|sell|2971.14| 2.1E-6|2026-01-01T05:01:...|2026-01-01T05:01:...|2026-01-01 12:01:...|2026010112|
# |684178|ETH-USD|751204807|sell|2971.14| 2.7E-7|2026-01-01T05:01:...|2026-01-01T05:01:...|2026-01-01 12:01:...|2026010112|
# |684179|ETH-USD|751204808|sell|2971.14|1.34E-6|2026-01-01T05:01:...|2026-01-01T05:01:...|2026-01-01 12:01:...|2026010112|
# +------+-------+---------+----+-------+-------+--------------------+--------------------+--------------------+----------+
# only showing top 5 rows

# %% [markdown]
# #### 2.2.2. Checking data quality

# %%
del_table = spark.sql(f"""
DELETE FROM delta.`{stream_table_path}`
WHERE to_date(exchange_time_ts) < DATE '2026-01-01'
""")

del_tablev.result()
# Out:
# DataFrame[num_affected_rows: bigint]

# %%
spark.conf.set(
    "spark.databricks.delta.retentionDurationCheck.enabled", "false"
)

spark.sql(f"""
VACUUM delta.`{stream_table_path}` RETAIN 0 HOURS
""").show(truncate=False)
# Out:
# Deleted 15208 files and directories in a total of 22 directories.
# +-----------------------------------------------------------------+
# |path                                                             |
# +-----------------------------------------------------------------+
# |file:/opt/consumer-output-delta-lake/delta-trades-stream-5s-table|
# +-----------------------------------------------------------------+

# %%
spark.sql(f"""
    SELECT
    extract(day from exchange_time_ts) as day,
    extract(hour from exchange_time_ts) as hour,
    extract(minute from exchange_time_ts) as min
    , max(CAST(ingest_time AS TIMESTAMP) + INTERVAL 7 HOURS) as ingestion_time
    , count(distinct trade_id) as trade_cnt
    FROM stream_trades
    group by 1,2,3
    order by day desc, hour desc, min desc
""").show(truncate=False)
# Out:
# [Stage 59:===================================================>    (11 + 1) / 12]
# +---+----+---+--------------------------+---------+
# |day|hour|min|ingestion_time            |trade_cnt|
# +---+----+---+--------------------------+---------+
# |1  |13  |17 |2026-01-01 13:17:23.185972|232      |
# |1  |13  |16 |2026-01-01 13:17:00.388338|541      |
# |1  |13  |15 |2026-01-01 13:16:00.298679|499      |
# |1  |13  |14 |2026-01-01 13:15:00.228302|606      |
# |1  |13  |13 |2026-01-01 13:14:00.171457|548      |
# |1  |13  |12 |2026-01-01 13:13:01.137763|588      |
# |1  |13  |11 |2026-01-01 13:11:24.277941|308      |
# |1  |13  |10 |2026-01-01 13:11:01.039313|652      |
# |1  |13  |9  |2026-01-01 13:10:00.863982|564      |
# |1  |13  |8  |2026-01-01 13:09:00.873746|598      |
# |1  |13  |7  |2026-01-01 13:08:00.547825|672      |
# |1  |13  |6  |2026-01-01 13:07:00.697651|534      |
# |1  |13  |5  |2026-01-01 13:06:00.566139|546      |
# |1  |13  |4  |2026-01-01 13:05:00.473353|536      |
# |1  |13  |3  |2026-01-01 13:04:00.47114 |669      |
# |1  |13  |2  |2026-01-01 13:03:00.263502|688      |
# |1  |13  |1  |2026-01-01 13:02:00.26025 |648      |
# |1  |13  |0  |2026-01-01 13:01:00.137859|609      |
# |1  |12  |59 |2026-01-01 12:59:59.995975|519      |
# |1  |12  |58 |2026-01-01 12:59:01.035436|595      |
# +---+----+---+--------------------------+---------+
# only showing top 20 rows

# %% [markdown]
# #### 2.2.3. Data transformation

# %%
df_5min = spark.sql("""
    SELECT
        window.start AS window_start,
        window.end AS window_end,
        symbol,
        COUNT(*) AS trade_count,
        SUM(case when side = 'buy' then size end) AS volume_buy,
        SUM(case when side = 'sell' then size end) AS volume_sell,
        AVG(price) AS avg_price,
        MIN(price) AS min_price,
        MAX(price) AS max_price,
        LAST(price, TRUE) AS close_price,  -- last trade price in window
        FIRST(price, TRUE) AS open_price   -- first trade price in window
    FROM (
        SELECT *,
               window(exchange_time_ts, '5 minutes') AS window
        FROM stream_trades
    )
    GROUP BY window, symbol
    ORDER BY window_start DESC, symbol
""")

df_5min.printSchema()
df_5min.show(10, truncate=False)
# Out:
# root
#  |-- window_start: timestamp (nullable = true)
#  |-- window_end: timestamp (nullable = true)
#  |-- symbol: string (nullable = true)
#  |-- trade_count: long (nullable = false)
#  |-- volume_buy: double (nullable = true)
#  |-- volume_sell: double (nullable = true)
#  |-- avg_price: double (nullable = true)
#  |-- min_price: double (nullable = true)
#  |-- max_price: double (nullable = true)
#  |-- close_price: double (nullable = true)
#  |-- open_price: double (nullable = true)
# [Stage 154:==================================================>    (37 + 3) / 40]
# +-------------------+-------------------+-------+-----------+------------------+------------------+-------------------+---------+---------+-----------+----------+
# |window_start       |window_end         |symbol |trade_count|volume_buy        |volume_sell       |avg_price          |min_price|max_price|close_price|open_price|
# +-------------------+-------------------+-------+-----------+------------------+------------------+-------------------+---------+---------+-----------+----------+
# |2025-12-29 16:45:00|2025-12-29 16:50:00|ADA-USD|364        |162364.71059076997|109395.70658647   |0.36769670329670345|0.3669   |0.3687   |0.3676     |0.3673    |
# |2025-12-29 16:45:00|2025-12-29 16:50:00|BTC-USD|3482       |40.28869031000001 |10.846198720000007|87960.60836588149  |87869.59 |88134.36 |87921.37   |88020.0   |
# |2025-12-29 16:45:00|2025-12-29 16:50:00|ETH-USD|1360       |210.04045015000008|170.71252654000006|2959.5825882352938 |2953.72  |2967.72  |2959.32    |2963.21   |
# |2025-12-29 16:45:00|2025-12-29 16:50:00|SOL-USD|907        |2187.999958150001 |992.15056871      |125.69019845644989 |125.51   |125.99   |125.69     |125.79    |
# |2025-12-29 16:45:00|2025-12-29 16:50:00|XRP-USD|570        |124947.69106      |80142.62377700002 |1.8675477192982461 |1.8642   |1.8717   |1.8694     |1.869     |
# |2025-12-29 16:40:00|2025-12-29 16:45:00|ADA-USD|325        |270328.95858176006|94916.55402832001 |0.3689618461538461 |0.3683   |0.3702   |0.3685     |0.3685    |
# |2025-12-29 16:40:00|2025-12-29 16:45:00|BTC-USD|3519       |33.84404667       |16.767736780000014|88198.91117647056  |88077.52 |88498.12 |88180.99   |88237.42  |
# |2025-12-29 16:40:00|2025-12-29 16:45:00|ETH-USD|2171       |315.3114504499999 |199.10098303      |2970.9474850299403 |2961.23  |2985.91  |2968.7     |2964.37   |
# |2025-12-29 16:40:00|2025-12-29 16:45:00|SOL-USD|1350       |6881.056031379992 |4384.25376304     |126.08551111111107 |125.82   |126.63   |126.09     |126.05    |
# |2025-12-29 16:40:00|2025-12-29 16:45:00|XRP-USD|1301       |1078166.764371999 |241999.1877739999 |1.8704640276710223 |1.8637   |1.8773   |1.8694     |1.8719    |
# +-------------------+-------------------+-------+-----------+------------------+------------------+-------------------+---------+---------+-----------+----------+
# only showing top 10 rows

# %% [markdown]
# ## 3. Time travel

# %%
# Read the table as it existed at a specific time
df_past = spark.sql(f"""
    SELECT * FROM delta.`{table_path}`
    TIMESTAMP AS OF '2025-12-28 19:00:00'
""")
df_past.count()
# Out:
# 1724793

# %%
# Read the table as it existed at a specific time
df_current = spark.sql(f"""
    SELECT * FROM delta.`{table_path}`
""")
df_current.count()
# Out:
# 2298468
